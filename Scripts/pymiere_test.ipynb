# %%
import pymiere
print(pymiere.objects.app.isDocumentOpen())
# Out:
# True

# %%
project = pymiere.objects.app.project
project

# %%
qe_project = pymiere.objects.qe.project  
# see all available video effects  
print(list(qe_project.getVideoEffectList()))
# Out:
# ['Antialias', 'Bend', 'Camera View', 'Color Balance (RGB)', 'Color Replace', 'Gamma Correction', 'Extract', 'Color Pass', 'Ghosting', 'Horizontal Hold', 'Lens Distortion', 'Solarize', 'Vertical Hold', 'Convolution Kernel', 'Levels', 'Auto Color', 'Auto Contrast', 'Auto Levels', 'Alpha Adjust', 'Alpha Glow', 'Arithmetic', 'ASC CDL', 'Auto Reframe', 'Brightness & Contrast', 'Basic 3D', 'Bevel Alpha', 'Bevel Edges', 'Black & White', 'Blend', 'Block Dissolve', 'Blue Screen Key', 'Broadcast Colors', 'Brush Strokes', 'Calculations', 'Camera Blur', 'Cell Pattern', 'Change to Color', 'Change Color', 'Channel Blur', 'Channel Mixer', 'Checkerboard', 'Chroma Key', 'Cineon Converter', 'Circle', 'Clip Name', 'Fast Color Corrector', 'RGB Color Corrector', 'Color Space Transform', '4-Color Gradient', 'Three-Way Color Corrector', 'Color Balance', 'Color Emboss', 'Color Balance (HLS)', 'Color Key', 'Compound Arithmetic', 'Compound Blur', 'Corner Pin', 'Crop', 'Difference Matte', 'Video Limiter', 'Directional Blur', 'Drop Shadow', 'Dust & Scratches', 'Echo', 'Edge Feather', 'Ellipse', 'Emboss', 'Equalize', 'Eyedropper Fill', 'Fast Blur', 'Reduce Interlace Flicker', 'Find Edges', 'Four-Point Garbage Matte', 'Sixteen-Point Garbage Matte', 'Eight-Point Garbage Matte', 'Gaussian Blur', 'Gradient Wipe', 'Vector Motion', 'Group', 'Grid', 'Horizontal Flip', 'Image Matte Key', 'Invert', 'Leave Color', 'Lens Flare', 'Lighting Effects', 'Lightning', 'Linear Wipe', 'Luma Corrector', 'Luma Curve', 'Luma Key', 'Lumetri Color', 'Magnify', 'Mask', 'Mask2', 'Median (Legacy)', 'Metadata & Timecode Burn-in', 'Mirror', 'Mosaic', 'Noise', 'Noise', 'Noise Alpha', 'Noise Alpha', 'Noise HLS', 'Noise HLS', 'Noise HLS Auto', 'Noise HLS Auto', 'Non Red Key', 'Offset', 'Paint Bucket', 'Posterize', 'Posterize Time', 'ProcAmp', 'Radial Shadow', 'Radial Wipe', 'Ramp', 'Remove Matte', 'Replicate', 'RGB Curves', 'RGB Difference Key', 'Pixel Motion Blur', 'Rolling Shutter Repair', 'Timewarp', 'Roughen Edges', 'SDR Conform', 'Set Matte', 'Set Matte', 'Shape', 'Sharpen', 'Simple Text', 'Solid Composite', 'Spherize', 'Warp Stabilizer', 'Strobe Light', 'Text', 'Texturize', 'Threshold', 'Threshold', 'Timecode', 'Tint', 'Track Matte Key', 'Transform', 'Transform', 'Turbulent Displace', 'Twirl', 'Ultra Key', 'Unsharp Mask', 'Venetian Blinds', 'Vertical Flip', 'Video Limiter (legacy)', 'VR Chromatic Aberrations', 'VR Color Gradients', 'VR De-Noise', 'VR Digital Glitch', 'VR Fractal Noise', 'VR Blur', 'VR Glow', 'VR Plane to Sphere', 'VR Projection', 'VR Rotate Sphere', 'VR Sharpen', 'Wave Warp', 'Write-on', 'Shadow/Highlight', 'MXF/ARRIRAW Development Settings', 'ARRIRAW Development Settings', 'Canon Cinema RAW Light Source Settings', 'CinemaDNG Source Settings', 'Cineon Source Settings', 'Sony Raw Source Settings', 'FI: Alpha FX', 'FI: Auto Align FX', 'FI: Blur FX', 'FI: Bokeh Blur FX', 'FI: Camera Shake FX', 'FI: Channel Mix FX', 'FI: Clone FX', 'FI: Compound Blur FX', 'FI: Rounded Crop FX', 'FI: Echo Glow FX', 'FI: Edge Glow FX', 'FI: Focus Blur FX', 'FI: Glint FX', 'FI: Grow FX', 'FI: Light Leaks FX', 'FI: Long Shadow FX', 'FI: Mosaic FX', 'FI: Move FX', 'FI: RGB Split FX', 'FI: 3D Rotate FX', 'FI: Shrink FX', 'FI: Spacer FX', 'FI: Spin FX', 'FI: Stroke FX', 'FI: Vignette FX', 'FI: Volumetric Rays FX', 'FI: Wiggle FX', 'FI: Wonder Glow FX', 'Motion', 'MPEG Source Settings', 'Opacity', 'PRORES RAW Source Settings', 'RED Source Settings', 'Sony RAW MXF Source Settings']

# %%
project

# %%
print(pymiere.objects.app.isDocumentOpen())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(pymiere.objects.app.isDocumentOpen())
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymiere\objects\start_vars.py:56, in StartVars.app(self)
#      54 @property
#      55 def app(self):
# ---> 56     return Application(**_eval_script_returning_object('app', as_kwargs=True))
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymiere\core.py:516, in _eval_script_returning_object(line, as_kwargs)
#     509 script = "var tmp = {}".format(line)
#     510 script += """\nif(typeof tmp === 'object' && tmp !== null){
#     511         var newPymiereId = $._pymiere.generateId();
#     512         $._pymiere[newPymiereId] = tmp;
#     513         tmp = ExtendJSON.stringify({"isObject": true, "objectType": tmp.reflect.name, "pymiereId": newPymiereId}, internal_variables_replacer, 0, 1);
#     514     }
#     515     tmp"""
# --> 516 result = eval_script(script, decode_json=True)
#     517 if as_kwargs and isinstance(result, dict) and result.get("isObject"):
#     518     kwargs = dict(pymiere_id=result["pymiereId"])
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymiere\core.py:77, in eval_script(code, filepath, decode_json)
#      68 def eval_script(code=None, filepath=None, decode_json=True):
#      69     """
#      70     Send some ExtendScript code to premiere and wait for the returning value
#      71
#    (...)     75     :return: (any) depend on the returned value
#      76     """
# ---> 77     check_premiere_is_alive(crash=True)
#      79     # arg check
#      80     if not any([code, filepath]):
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymiere\core.py:34, in check_premiere_is_alive(crash)
#      32 msg = "Premiere Pro is not running"
#      33 if crash:
# ---> 34     raise ValueError(msg)
#      35 print(msg)
#      36 return False
#
# ValueError: Premiere Pro is not running
