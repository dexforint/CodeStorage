# %%
from fp.fp import FreeProxy

# %%
proxy = FreeProxy(country_id=['US'], ).get()
# Out:
# ---------------------------------------------------------------------------
# FreeProxyException                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 proxy = FreeProxy(country_id=['US']).get()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\fp\fp.py:87, in FreeProxy.get(self, repeat)
#      85     if self.country_id is not None:
#      86         self.country_id = None
# ---> 87     return self.get(repeat=True)
#      88 raise FreeProxyException(
#      89     'There are no working proxies at this time.')
#
# File ~\AppData\Roaming\Python\Python314\site-packages\fp\fp.py:88, in FreeProxy.get(self, repeat)
#      86         self.country_id = None
#      87     return self.get(repeat=True)
# ---> 88 raise FreeProxyException(
#      89     'There are no working proxies at this time.')
#
# FreeProxyException: There are no working proxies at this time.

# %%
proxy
